# %%
import numpy as np
import pandas as pd

pd.read_csv('dataset/train.csv',nrows=200)
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0              842     0          2.2         0   1       0           7
# 1             1021     1          0.5         1   0       1          53
# 2              563     1          0.5         1   2       1          41
# 3              615     1          2.5         0   0       0          10
# 4             1821     1          1.2         0  13       1          44
# ..             ...   ...          ...       ...  ..     ...         ...
# 195           1526     0          2.1         0   1       1          23
# 196           1989     0          2.5         1   0       1          41
# 197           1308     0          1.9         0   0       1          61
# 198            609     0          0.5         0   3       0          26
# 199           1905     0          0.6         1   9       1          36
#
#      m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
pd.read_csv('dataset/train.csv')
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
for chunk in pd.read_csv('dataset/train.csv',chunksize=200):
    print(chunk)
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0              842     0          2.2         0   1       0           7
# 1             1021     1          0.5         1   0       1          53
# 2              563     1          0.5         1   2       1          41
# 3              615     1          2.5         0   0       0          10
# 4             1821     1          1.2         0  13       1          44
# ..             ...   ...          ...       ...  ..     ...         ...
# 195           1526     0          2.1         0   1       1          23
# 196           1989     0          2.5         1   0       1          41
# 197           1308     0          1.9         0   0       1          61
# 198            609     0          0.5         0   3       0          26
# 199           1905     0          0.6         1   9       1          36
#
#      m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
pd.read_html('https://en.wikipedia.org/wiki/El_Cl%C3%A1sico')
# Out:
# [                                                    0  \
#  0   Team kits – Real Madrid in white, Barcelona in...
#  1                                              Locale
#  2                                               Teams
#  3                                       First meeting
#  4                                      Latest meeting
#  5                                            Stadiums
#  6                                          Statistics
#  7                                      Meetings total
#  8                                           Most wins
#  9                             Most player appearances
#  10                                         Top scorer
#  11                                    Largest victory
#
#                                                      1
#  0   Team kits – Real Madrid in white, Barcelona in...
#  1                                               Spain
#  2                                BarcelonaReal Madrid
# ...

# %%
table = pd.read_html('https://en.wikipedia.org/wiki/El_Cl%C3%A1sico')

# %%
table[0]
# Out:
#                                                     0  \
# 0   Team kits – Real Madrid in white, Barcelona in...
# 1                                              Locale
# 2                                               Teams
# 3                                       First meeting
# 4                                      Latest meeting
# 5                                            Stadiums
# 6                                          Statistics
# 7                                      Meetings total
# 8                                           Most wins
# 9                             Most player appearances
# 10                                         Top scorer
# 11                                    Largest victory
#
#                                                     1
# 0   Team kits – Real Madrid in white, Barcelona in...
# 1                                               Spain
# 2                                BarcelonaReal Madrid
# ...

# %%
table[0].to_csv('dataset\Classico Tables.csv')

# %%
table[1].to_pickle('dataset\Classico Tables Pickle')

# %%
table[3]
# Out:
#        #             Player          For     Score              Date  \
# 0    1.0        Jim Carlier    Barcelona   7–0 (H)   1 November 1913
# 1    2.0  Santiago Bernabéu  Real Madrid   4–1 (H)      2 April 1916
# 2    3.0      Luis Belaunde  Real Madrid   6–6 (N)     13 April 1916
# 3    4.0  Paulino Alcántara    Barcelona   6–6 (N)     13 April 1916
# 4    5.0  Santiago Bernabéu  Real Madrid   6–6 (N)     13 April 1916
# 5    6.0   Francesc Vinyals    Barcelona   3–1 (H)   1 November 1917
# 6    7.0  Paulino Alcántara    Barcelona   7–1 (H)  18 February 1920
# 7    8.0     Josep Samitier    Barcelona   1–5 (A)     18 April 1926
# 8    9.0      Jaime Lazcano  Real Madrid   5–1 (H)     30 March 1930
# 9   10.0      Jaime Lazcano  Real Madrid   8–2 (H)   3 February 1935
# 10  11.0  Ildefonso Sañudo4  Real Madrid   8–2 (H)   3 February 1935
# 11  12.0    Martí Ventolrà4    Barcelona   5–0 (H)     21 April 1935
# 12  13.0             Pruden  Real Madrid  11–1 (H)      13 June 1943
# ...

# %%
i = 1
ind = 0
writer = pd.ExcelWriter('dataset\Classico tables.xlsx', engine='xlsxwriter')
for t in table:
    t.to_excel(writer, sheet_name='Sheet'+str(i))
    i+=1
writer.save()

# %%
len(table[0])
# Out:
# 12

# %%
len(table[1])
# Out:
# 9

# %%
import sqlite3
